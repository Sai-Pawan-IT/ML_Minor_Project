# %% [markdown]
# # --------------------------------ML_MINOR_PROJECT----------------------------------------------

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('DataCoSupplyChainDataset.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %% [markdown]
# ## 1) List all the cities and the respective number of pending orders in 'India'?

# %%
po=df[(df['Order Country']=='India')&(df['Order Status']=='PENDING')]

# %%
po
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1       TRANSFER                         5                              4
# 21      TRANSFER                         5                              4
# 45      TRANSFER                         6                              4
# 46      TRANSFER                         5                              2
# 382     TRANSFER                         3                              4
# ...          ...                       ...                            ...
# 180142  TRANSFER                         4                              4
# 180164  TRANSFER                         2                              1
# 180248  TRANSFER                         5                              2
# 180331  TRANSFER                         3                              4
# 180405  TRANSFER                         2                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
pd.DataFrame(po['Order City'].value_counts())
# Out:
#             Order City
# Kanpur              25
# Pune                24
# Bangalore           24
# Lucknow             21
# Delhi               18
# ...                ...
# Chandigarh           1
# Hisar                1
# Hubli                1
# Bhopal               1
# Ghaziabad            1
#
# [91 rows x 1 columns]

# %% [markdown]
# ## 2) Which country has the most suspected fraud?

# %%
fraud = df[df["Order Status"]=="SUSPECTED_FRAUD"]

# %%
fraud
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 10      TRANSFER                         6                              2
# 24      TRANSFER                         2                              2
# 183     TRANSFER                         5                              4
# 184     TRANSFER                         5                              4
# 185     TRANSFER                         6                              4
# ...          ...                       ...                            ...
# 180274  TRANSFER                         5                              2
# 180309  TRANSFER                         2                              1
# 180352  TRANSFER                         4                              4
# 180406  TRANSFER                         6                              4
# 180490  TRANSFER                         4                              4
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
f=fraud["Order Country"].value_counts()

# %%
pd.DataFrame(f[[0,]])
# Out:
#                 Order Country
# Estados Unidos            573

# %% [markdown]
# ## 3) Which product(s) has/have the maximum discount?

# %%
discount=df[df["Order Item Discount"]==df["Order Item Discount"].max()]

# %%
pd.DataFrame(discount["Product Name"])
# Out:
#               Product Name
# 12606  SOLE E35 Elliptical

# %% [markdown]
# ## 4) Which year had the minimum sales for "Nike" products?

# %%
df["Product Name"]=df["Product Name"].str.slice(0,4)

# %%
df["Product Name"]
# Out:
# 0         Smar
# 1         Smar
# 2         Smar
# 3         Smar
# 4         Smar
#           ...
# 180514    Fiel
# 180515    Fiel
# 180516    Fiel
# 180517    Fiel
# 180518    Fiel
# Name: Product Name, Length: 180519, dtype: object

# %%
Nike=df[df["Product Name"]=="Nike"]

# %%
pd.DataFrame(Nike['shipping date (DateOrders)'].value_counts())
# Out:
#                  shipping date (DateOrders)
# 3/13/2017 3:26                            8
# 1/18/2015 12:46                           8
# 12/24/2016 7:34                           8
# 2/20/2016 11:09                           7
# 2/5/2016 15:33                            7
# ...                                     ...
# 2/13/2015 23:04                           1
# 8/5/2017 9:43                             1
# 1/8/2016 2:17                             1
# 10/23/2015 9:13                           1
# 2/9/2017 20:59                            1
#
# [36643 rows x 1 columns]

# %% [markdown]
# ## 5) How many successfully processed orders have days for shipping real (Real) > Days for shipment (Scheduled)?

# %%
Completed=df[(df["Order Status"]=="COMPLETE")]

# %%
Completed
# Out:
#          Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0       DEBIT                         3                              4
# 3       DEBIT                         3                              4
# 6       DEBIT                         2                              1
# 13      DEBIT                         2                              1
# 15      DEBIT                         2                              1
# ...       ...                       ...                            ...
# 180500  DEBIT                         3                              4
# 180505  DEBIT                         2                              4
# 180508  DEBIT                         4                              2
# 180512  DEBIT                         6                              4
# 180515  DEBIT                         3                              2
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
C=Completed[Completed["Days for shipping (real)"]>Completed["Days for shipment (scheduled)"]]

# %%
C
# Out:
#          Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 6       DEBIT                         2                              1
# 13      DEBIT                         2                              1
# 15      DEBIT                         2                              1
# 18      DEBIT                         2                              1
# 25      DEBIT                         6                              2
# ...       ...                       ...                            ...
# 180479  DEBIT                         6                              4
# 180499  DEBIT                         4                              2
# 180508  DEBIT                         4                              2
# 180512  DEBIT                         6                              4
# 180515  DEBIT                         3                              2
#
#         Benefit per order  Sales per customer Delivery Status  \
# ...

# %%
len(C)
# Out:
# 34199
